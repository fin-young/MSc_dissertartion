# %%
import FX_DATA_GEN as DG
from THEO_POULA_Model import LSTMModel, get_model ,LSTMClassifier

import pandas as pd
import numpy as np
from numpy import hstack, array
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import torch 
from torch import nn
import torch.nn.functional as F
from datetime import datetime
from Theopoula import THEOPOULA
from THEO_POULA_Train import THEO_POULA_TRAIN,  Classify_Train
from THEO_POULA_Plot import prob_plot, optim_plot, multi_probs_plot
from torch.utils.tensorboard import SummaryWriter
import os
import matplotlib.pyplot as plt
import pickle as pkl
import seaborn as sns

# %%
optim_plot('KRW')
# Out:
# AMSGrad:  test_loss - 1.5626002059263342
# ADAM:  test_loss - 1.4514108300209045
# RMSprop:  test_loss - 1.4938974029877607
# THEOPOULA:  test_loss - 1.8765232282526352

# %%
#daily FX Rate dataset call
#DG.Get_curr_data('MX')

# %%
DG.MacEcon_TS('CZ',1980, 2020)

# %%
#Description of Macro economic dataset
#DG.describe_MacEcon_TS(MEX)

# %%
#DG.Get_curr_code('KR')

# %% [markdown]
# ## Create dataset & Clean

# %%
#Joint dataset of Macro economic & FX Rates combined
Loaded_data = DG.Get_FX_MacEcon_Data('TH')
currency_code = Loaded_data.iloc[:,0].name
targ_nme = Loaded_data.iloc[:,-1].name
print('Currency Code under investigation: ',currency_code)
Loaded_data.head()
# Out:
# Currency Code under investigation:  THB
#               THB    Yr  DoM  MoY   sin_DoY   cos_DoY  \
# Date
# 1981-05-12  20.75  1981   12    5  0.774884 -0.632103
# 1981-05-13  20.75  1981   13    5  0.763889 -0.645348
# 1981-05-14  20.75  1981   14    5  0.752667 -0.658402
# 1981-05-15  21.00  1981   15    5  0.741222 -0.671260
# 1981-05-18  21.00  1981   18    5  0.705584 -0.708627
#
#             Ave Monthly USD FX Rate @OBS_STATUS_x  Inflation (CPI) %  \
# Date
# 1981-05-12                20.939106           NaN           36.42852
# 1981-05-13                20.939106           NaN           36.42852
# 1981-05-14                20.939106           NaN           36.42852
# 1981-05-15                20.939106           NaN           36.42852
# 1981-05-18                20.939106           NaN           36.42852
#
#            @OBS_STATUS_y  ...  Total Debt(USD)  Short Term Debt(USD)  \
# Date                      ...
# ...

# %%
# Save Loaded File to stop having to re-search from the API

file_name= (f'loaded_data_{currency_code}.csv')
save_dir = "./Datasets/"

if not os.path.isdir(save_dir):
    os.mkdir(save_dir)
Loaded_data.to_csv(save_dir+file_name, index=True)

# %% [markdown]
# ### Load pre-created Dataset

# %%
CURR_TO_LOAD = 'MYR'
Loaded_data = pd.read_csv(f'./Datasets/loaded_data_{CURR_TO_LOAD}.csv').set_index(['Date'])
Loaded_data.index = pd.to_datetime(Loaded_data.index)
currency_code = Loaded_data.iloc[:,0].name
targ_nme = Loaded_data.iloc[:,-1].name
print('Currency Code under investigation: ',currency_code)
Loaded_data.head()
# Out:
# Currency Code under investigation:  MYR
#                MYR    Yr  DoM  MoY   sin_DoY   cos_DoY  \
# Date
# 1980-05-09  2.2065  1980    9    5  0.799839 -0.600214
# 1980-05-12  2.1940  1980   12    5  0.767880 -0.640593
# 1980-05-13  2.1860  1980   13    5  0.756771 -0.653680
# 1980-05-14  2.1770  1980   14    5  0.745438 -0.666575
# 1980-05-15  2.1780  1980   15    5  0.733885 -0.679273
#
#             Ave Monthly USD FX Rate  Inflation (CPI) %  \
# Date
# 1980-05-09                   2.1877          40.803949
# 1980-05-12                   2.1877          40.803949
# 1980-05-13                   2.1877          40.803949
# 1980-05-14                   2.1877          40.803949
# 1980-05-15                   2.1877          40.803949
#
#             Deposit Interest Rate %  Lending Interest Rate %  ...  \
# Date                                                          ...
# 1980-05-09                      5.5                      NaN  ...
# ...

# %%
#Description to know which columns to remove from dataframe
DG.describe_MacEcon_TS(Loaded_data)
# Out:
#                               Features First Valid Last Valid  Null Values
# 0                                  THB  1981-05-12 2020-11-30            0
# 1                                   Yr  1981-05-12 2020-11-30            0
# 2                                  DoM  1981-05-12 2020-11-30            0
# 3                                  MoY  1981-05-12 2020-11-30            0
# 4                              sin_DoY  1981-05-12 2020-11-30            0
# 5                              cos_DoY  1981-05-12 2020-11-30            0
# 6              Ave Monthly USD FX Rate  1981-05-12 2020-11-30            0
# 7                        @OBS_STATUS_x  1997-07-01 1997-07-31         9828
# 8                    Inflation (CPI) %  1981-05-12 2020-11-30            0
# 9                        @OBS_STATUS_y  1986-01-02 2009-01-30         9789
# 10             Lending Interest Rate %  1981-05-12 2020-11-30          522
# ...

# %%
cloned_data = Loaded_data.copy()

# %%
#Add one hot dummy columns for month
cloned_data = (DG.Add_dummy_MoY(cloned_data))


if currency_code == 'TRY':
    #____________________Turkey_____________________________
    #Description of cleaned and one-hott'ed dataset
    cloned_data.drop(columns = ['@OBS_STATUS_x', '@OBS_STATUS_y',
                            'M2/Reserves',# Nan Values
                            'M2 Multiplier Growth (%)', # Data flatlines in 2008
                            'Domestic Credit to GDP', # Nan Values
                            'Total Debt(USD)', # Nan Values
                            'Short Term Debt(USD)', # Nan Values
                            'cos_DoY',
                            'Yr',
                            'DoM'], inplace = True)   
    cloned_data.dropna(axis=0, subset = ['Portfolio Investments(USD)'], inplace = True)
if currency_code == 'KRW':
    #____________________#South Korea_____________________________
    #Description of cleaned and one-hott'ed dataset
    cloned_data.drop(columns = ['@OBS_STATUS_x', '@OBS_STATUS_y',
                            'M2/Reserves',# Nan Values
                            'M2 Multiplier Growth (%)', # Data flatlines in 2008
                            'Domestic Credit to GDP', # Nan Values
                            'Total Debt(USD)', # Nan Values
                            'Short Term Debt(USD)', # Nan Values
                            'cos_DoY',
                            'Yr',
                            'DoM'], inplace = True)
    #Fields with the same end date    
    cloned_data.dropna(axis=0, subset = ['Deposit Interest Rate %','Lending Interest Rate %','Trade Openness'], inplace = True)
    #'Exports(USD)''Imports (USD)'
    #cloned_data.interpolate(method='polynomial',order =2,limit_direction='forward', axis=0, inplace=True)
    
if currency_code == 'INR':
    #____________________India_____________________________
    #Description of cleaned and one-hott'ed dataset
    cloned_data.drop(columns = ['@OBS_STATUS_x', '@OBS_STATUS_y',
                            'M2/Reserves',# Nan Values
                            'M2 Multiplier Growth (%)', # Data flatlines in 2008
                            'Portfolio Investments(USD)',
                            'Total Debt(USD)', # Nan Values
                            'Short Term Debt(USD)', # Nan Values
                            'cos_DoY',
                            'Yr',
                            'DoM'], inplace = True)
    #Fields with the same end date    
    cloned_data.dropna(axis=0, subset = ['GDP % Growth','Domestic Credit to GDP'], inplace = True)
    #'Exports(USD)''Imports (USD)'
    #cloned_data.interpolate(method='polynomial',order =2,limit_direction='forward', axis=0, inplace=True)    
if currency_code == 'THB':
    #____________________#THILAND_____________________________
    #Description of cleaned and one-hott'ed dataset
    cloned_data.drop(columns = ['@OBS_STATUS_x', '@OBS_STATUS_y',
                            'M2/Reserves',# Nan Values
                            'M2 Multiplier Growth (%)', # Data flatlines in 2008
                            'Domestic Credit to GDP', # Nan Values
                            'Portfolio Investments(USD)',# Nan Values
                            'Total Debt(USD)', # Nan Values
                            'Short Term Debt(USD)', # Nan Values
                            'Umemployment rate(%)', # Nan Values
                            'cos_DoY',
                            'Yr',
                            'DoM'], inplace = True)
    #Fields with the same end date


    cloned_data.dropna(axis=0, subset = ['Imports (USD)','Trade Openness'], inplace = True)

    # Interpolate Real :'Interest Rate(%)','Deposit Interest Rate %','Lending Interest Rate %'
    #cloned_data.interpolate(method='polynomial',order =2,limit_direction='forward', axis=0, inplace=True)
    for i in ['Real Interest Rate(%)','Deposit Interest Rate %','Lending Interest Rate %']:
        cloned_data[i]=cloned_data[i].interpolate(method='polynomial',order =2,limit_direction='forward', axis=0)
    #cloned_data['Real Interest Rate(%)']=cloned_data['Real Interest Rate(%)'].interpolate(method='polynomial',order =2,limit_direction='forward', axis=0, inplace=True)
    
    
if currency_code == 'MXN':
    #____________________#MEXICO_____________________________
    #Description of cleaned and one-hott'ed dataset
    cloned_data.drop(columns = ['M2/Reserves',# Nan Values
                                 'M2 Multiplier Growth (%)', # Data flatlines in 2008
                            'Domestic Credit to GDP', # Nan Values
                            'Portfolio Investments(USD)',# Nan Values
                            'Total Debt(USD)', # Nan Values
                            'Short Term Debt(USD)', # Nan Values
                            'Umemployment rate(%)', # Nan Values
                            'cos_DoY',
                            'Yr',
                            'DoM',
                            'M2 Multiplier Growth (%)', # Data flatlines in 2008
                            'Imports (USD)', # Severe drop in value in 1990s skews data; removing due to this and 1.5yr lack of data
                            'Trade Openness',# Derived from Imports, therefore removed also
                             #'Gov Consumption Expendature (%GDP)',# Annual Value, Removing to aid model Training 
                             'Ave Monthly USD FX Rate'#, # Future dated Data, cannot add to model
                             #'Capital Formations(USD)', #  Annual Value, Removing to aid model Training 
                             #'GDP % Growth'#  Annual Value, Removing to aid model Training: Exaggeration of raw GDP value
                            ], inplace = True)
if currency_code == 'MYR':
    #____________________Malaysia_____________________________
    #Description of cleaned and one-hott'ed dataset
    cloned_data.drop(columns = ['M2/Reserves',# Nan Values
                            'Domestic Credit to GDP', # Nan Values
                            'Portfolio Investments(USD)',# Nan Values
                            'Total Debt(USD)', # Nan Values
                            'Short Term Debt(USD)', # Nan Values
                            'Umemployment rate(%)', # Nan Values
                            'Current Account(%GDP)',
                            'FDI(%GDP)',
                            'cos_DoY',
                            'Yr',
                            'DoM',
                            'M2 Multiplier Growth (%)', # Data flatlines in 2008

                            ], inplace = True)
    #Fields with the same end date    
    cloned_data.dropna(axis=0, subset = ['GDP % Growth','Lending Interest Rate %'], inplace = True)
    # Interpolate Real :'REED 12mth std dev','Lending Interest Rate %'
    cloned_data.interpolate(method='polynomial',order =2,limit_direction='forward', axis=0, inplace=True)
    #cloned_data['Lending Interest Rate %']=cloned_data['Lending Interest Rate %'].interpolate(method='polynomial',order =2,limit_direction='forward', axis=0, inplace=True)
    #cloned_data['Real Interest Rate(%)']=cloned_data['Real Interest Rate(%)'].interpolate(method='polynomial',order =2,limit_direction='forward', axis=0, inplace=True)
    
    
    
X = cloned_data.copy()
cols = [currency_code,currency_code+'_classifier', currency_code+'_90d_change']
cntry = DG.Get_country_name(currency_code)
X = X[cols]
New_Columns= '%Change in FX Rate over 90 Day Period'
X[New_Columns] = X[currency_code+'_90d_change']
fig, ax = plt.subplots(nrows =1, ncols = 1, figsize=(8,6))
ax = sns.histplot(data=X, x=New_Columns, hue=currency_code+'_classifier', )
fig.suptitle(f'{cntry} Classification Distribution - Indicator of 90 Change in FX Rate')
    
# Replace the classifier to the end of the dataset

to_drop = currency_code+'_90d_change' #Drop the 90 FX Rate which is not needed. 
cloned_data.drop(columns = [to_drop], inplace = True)
end = [currency_code + '_classifier']
the_rest = [col for col in cloned_data.columns if col  not in end ]
new_order = the_rest + end
cloned_data = cloned_data.reindex(columns=new_order)    
    
# Save Loaded File to stop having to re-search from the API

file_name= (f'cleaned_data_{currency_code}.csv')
save_dir = "./Datasets/"

if not os.path.isdir(save_dir):
    os.mkdir(save_dir)
cloned_data.to_csv(save_dir+file_name, index=True)

DG.describe_MacEcon_TS(cloned_data)
# Out:
#                               Features First Valid Last Valid  Null Values
# 0                                  THB  1981-05-12 2020-07-31            0
# 1                              sin_DoY  1981-05-12 2020-07-31            0
# 2              Ave Monthly USD FX Rate  1981-05-12 2020-07-31            0
# 3                    Inflation (CPI) %  1981-05-12 2020-07-31            0
# 4              Lending Interest Rate %  1981-05-12 2020-07-31            0
# 5              Deposit Interest Rate %  1981-05-12 2020-07-31            0
# 6                         Exports(USD)  1981-05-12 2020-07-31            0
# 7                        Imports (USD)  1981-05-12 2020-07-31            0
# 8                       NY.GDP.MKTP.CD  1981-05-12 2020-07-31            0
# 9                Real Interest Rate(%)  1981-05-12 2020-07-31            0
# 10        Foreign Exchange Reserves(%)  1981-05-12 2020-07-31            0
# ...

# %% [markdown]
# ### Load Cleaned Dataset

# %%
CURR_TO_LOAD = 'KRW'
Loaded_data = pd.read_csv(f'./Datasets/cleaned_data_{CURR_TO_LOAD}.csv').set_index(['Date'])
Loaded_data.index = pd.to_datetime(Loaded_data.index)
currency_code = Loaded_data.iloc[:,0].name
targ_nme = Loaded_data.iloc[:,-1].name
print('Currency Code under investigation: ',currency_code)
cloned_data = Loaded_data.copy()
cloned_data.head()
# Out:
# Currency Code under investigation:  KRW
#               KRW       sin_DoY  Ave Monthly USD FX Rate  Inflation (CPI) %  \
# Date
# 1996-07-01  809.9  1.716633e-02                   812.76           63.44339
# 1996-07-02  812.8  1.224647e-16                   812.76           63.44339
# 1996-07-03  806.0 -1.716633e-02                   812.76           63.44339
# 1996-07-05  813.7 -5.147875e-02                   812.76           63.44339
# 1996-07-08  814.2 -1.028210e-01                   812.76           63.44339
#
#             Lending Interest Rate %  Deposit Interest Rate %  Exports(USD)  \
# Date
# 1996-07-01                    11.17                     9.87  9.897000e+09
# 1996-07-02                    11.17                     9.87  9.897000e+09
# 1996-07-03                    11.17                     9.87  9.897000e+09
# 1996-07-05                    11.17                     9.87  9.897000e+09
# 1996-07-08                    11.17                     9.87  9.897000e+09
#
# ...

# %%
DG.describe_MacEcon_TS(cloned_data)
# Out:
#                               Features First Valid Last Valid  Null Values
# 0                                  KRW  1996-07-01 2020-06-30            0
# 1                              sin_DoY  1996-07-01 2020-06-30            0
# 2              Ave Monthly USD FX Rate  1996-07-01 2020-06-30            0
# 3                    Inflation (CPI) %  1996-07-01 2020-06-30            0
# 4              Lending Interest Rate %  1996-07-01 2020-06-30            0
# 5              Deposit Interest Rate %  1996-07-01 2020-06-30            0
# 6                         Exports(USD)  1996-07-01 2020-06-30            0
# 7                        Imports (USD)  1996-07-01 2020-06-30            0
# 8                       NY.GDP.MKTP.CD  1996-07-01 2020-06-30            0
# 9                Real Interest Rate(%)  1996-07-01 2020-06-30            0
# 10        Foreign Exchange Reserves(%)  1996-07-01 2020-06-30            0
# ...

# %%
code = currency_code+'_classifier'
cloned_data.groupby([code]).agg(Count=(code, 'count')).reset_index()
# Out:
#             THB_classifier  Count
# 0       Large Appreciation    669
# 1       Small Appreciation   4860
# 2      Small deppreciation   3240
# 3     Low Crash Confidence    671
# 4  Medium Crash Confidence     76
# 5    High Crash Confidence    253

# %% [markdown]
# ## Normalise & pre-process data for pytorch (3D array)

# %%
# Plot to see the time series of all features
X = cloned_data.copy()
cols = X.columns
fig, ax = plt.subplots(nrows = len(cols), ncols = 1, figsize=(10,20))
for i in range(len(cols)):
    ax[i].plot(X.index, X[cols[i]], label=cols[i])
    ax[i].set_xlabel('Time')
    ax[i].set_ylabel(cols[i], rotation=0)
fig.tight_layout()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Set parameters for test/train Data
n_steps = 90 # How many days considered for 1 output
batch_size = 32 #mini-batch size
test_ratio = 0.2  # Test/Train ratio is 80/20

#Set split param

val_ratio = test_ratio / (1 - test_ratio)

#Cut into Features and Target Variable
y_name = cloned_data.iloc[:,-1].name
X, y = cloned_data.drop([y_name], axis=1) , cloned_data[[y_name]]

# For categorical Data - Use Lable Encoder
enc = LabelEncoder()
#enc.classes_
y_enc = enc.fit_transform(y.to_numpy().ravel())
y=pd.DataFrame(y_enc, index=y.index)



#Train & Test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_ratio, shuffle=False)
#Train & Validation 
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_ratio, shuffle=False)

#Set class eights for classification
class_weights = compute_class_weight('balanced',np.arange(len(enc.classes_)),y_train.to_numpy().ravel())
print(class_weights)
print(enc.classes_)

#Normalise data using standard scalar
#Fit each row of data as an array
#from sklearn.preprocessing import MinMaxScaler
scaler = DG.get_scaler('minmax')#DG.get_scaler('standard')


X_train_arr = scaler.fit_transform(X_train)
#X_val_arr = scaler.transform(X_val)
X_test_arr = scaler.transform(X_test)

y_train_arr = y_train #scaler.fit_transform(y_train)
#y_val_arr = y_val #scaler.transform(y_val)
y_test_arr =y_test #scaler.transform(y_test)

#Stack the data back together before splitting the sequence
train_arr = hstack((X_train_arr, y_train_arr))
#val_arr = hstack((X_val_arr, y_val_arr))
test_arr = hstack((X_test_arr, y_test_arr))

#split sequence will create a lag of the past 300 entries of the dataframe

X_train_split, y_train_split = DG.split_sequences(train_arr,n_steps)
#X_val_split, y_val_split = DG.split_sequences(val_arr,n_steps)
X_test_split, y_test_split = DG.split_sequences(test_arr,n_steps)



train_features = torch.Tensor(X_train_split)
train_targets = torch.Tensor(y_train_split)
#val_features = torch.Tensor(X_val_split)
#val_targets = torch.Tensor(y_val_split)
test_features = torch.Tensor(X_test_split)
test_targets = torch.Tensor(y_test_split)

#Joint Tensor of 
train = TensorDataset(train_features, train_targets)
#val = TensorDataset(val_features, val_targets)
test = TensorDataset(test_features, test_targets)

train_loader = DataLoader(train, batch_size=batch_size, shuffle=False, drop_last=True)
#val_loader = DataLoader(val, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader = DataLoader(test, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader_one = DataLoader(test, batch_size=1, shuffle=False, drop_last=True)
# Out:
# [3.71759259 0.87663755 1.75327511 6.63636364 0.47712418 0.56390449]
# ['High Crash Confidence' 'Large Appreciation' 'Low Crash Confidence'
#  'Medium Crash Confidence' 'Small Appreciation' 'Small deppreciation']
# C:\Users\S1026623\Anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass classes=[0 1 2 3 4 5], y=[5 5 5 ... 5 5 5] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
plot_train, plot_test = pd.merge(X_train,y_train,left_index=True, right_index=True), pd.merge(X_test,y_test,left_index=True, right_index=True)
plot_train.iloc[:,-1] = enc.inverse_transform(plot_train.iloc[:,-1])
plot_train.rename(columns={0:'Classification'},inplace=True)
plot_test.iloc[:,-1] = enc.inverse_transform(plot_test.iloc[:,-1])
plot_test.rename(columns={0:'Classification'},inplace=True)
plot_train.head()

pd.merge(plot_train.groupby(['Classification']).agg(Count=('Classification', 'count')).reset_index(),plot_test.groupby(['Classification']).agg(Count=('Classification', 'count')).reset_index(), how='outer',on='Classification')
# Out:
#             Classification  Count_x  Count_y
# 0    High Crash Confidence      216      NaN
# 1       Large Appreciation      916    110.0
# 2     Low Crash Confidence      458    149.0
# 3  Medium Crash Confidence      121      2.0
# 4       Small Appreciation     1683    481.0
# 5      Small deppreciation     1424    463.0

# %%
plt.figure(1)
plt.plot(X_train.index, X_train.iloc[:,0], label='Values - Training Set')
#plt.plot(X_val.index, X_val.iloc[:,0], label='Values - Validation Set')
plt.plot(X_test.index, X_test.iloc[:,0], label='Values - Test Set')
plt.xlabel('Time')
plt.ylabel('FX Rate')
plt.legend()

# %% [markdown]
# ## Set Model & Optim Parameters :

# %%
#______________Set Model Parameter ___________________
input_dim = len(X_train.columns) #sequence length
output_dim = 6 #6 for classification - 1 for float
seq_length = n_steps
hidden_dim = 10 
layer_dim = 1
batch_size = batch_size
dropout_prob = 0.3
model_name = 'lstm'

num_epoch = 400


model_params = {'input_dim': input_dim,
                'hidden_dim' : hidden_dim,
                'seq_length' : seq_length,
                'layer_dim' : layer_dim,
                'output_dim' : output_dim,
                'dropout_prob' : dropout_prob}

model = get_model(model_name, model_params)
print("Building on model:",model)

#______________Set Hyper Parameters___________________
optimizer_name = 'THEOPOULA'
lr = 1e-5
eta = 0
beta = 1e15
r = 0
eps = 1e-3 # [1e-1 to 1e-4]
weight_decay = 1.2e-6 
optimiser_params = {'lr':lr,
                    'eta':eta,
                    'beta':beta,
                    'r': r,
                    'eps':eps,
                    'weight_decay':weight_decay}
#______________Confirm Directorys___________________
if optimizer_name == 'THEOPOULA':
    experiment_name = '%s_%s_bs{%d}_lr{%.1e}_epoch{%d}_eta{%.1e}_beta{%.1e}_r{%d}_eps{%.1e}' \
                      %(optimizer_name, model_name, batch_size, lr, num_epoch, eta, beta, r, eps)
else:
    experiment_name = '%s_%s_bs{%d}_lr{%.1e}_eps{%.1e}_epoch{%d}'%(optimizer_name, model_name, batch_size, lr, eps, num_epoch)
    
log_dir = './log/'
ckpt_dir = './ckpt/'
cur_dir = currency_code+'/'
log_dir = log_dir + cur_dir +experiment_name
ckpt_dir = ckpt_dir + cur_dir + experiment_name
print('Saving to History to:', log_dir)
print('Saving to States to:', ckpt_dir)
# Out:
# Building on model: LSTMModel(
#   (lstm): LSTM(34, 10, batch_first=True, dropout=0.3)
#   (fc): Linear(in_features=10, out_features=6, bias=True)
#   (drop): Dropout(p=0.3, inplace=False)
# )
# Saving to History to: ./log/KRW/THEOPOULA_lstm_bs{32}_lr{1.0e-05}_epoch{400}_eta{0.0e+00}_beta{1.0e+15}_r{0}_eps{1.0e-03}
# Saving to States to: ./ckpt/KRW/THEOPOULA_lstm_bs{32}_lr{1.0e-05}_epoch{400}_eta{0.0e+00}_beta{1.0e+15}_r{0}_eps{1.0e-03}
# C:\Users\S1026623\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py:60: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "

# %% [markdown]
# ## Trialling Classifier Model

# %%
class LSTMClassifier(nn.Module):
    """Very simple implementation of LSTM-based time-series classifier."""
    
    def __init__(self, input_dim, hidden_dim, layer_dim, output_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.layer_dim = layer_dim
        self.LSTM = nn.LSTM(input_dim, hidden_dim, layer_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.batch_size = None
        self.hidden = None
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    def forward(self, x):
        h0, c0 = self.init_hidden(x)
        out, (hn, cn) = self.LSTM(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out.to(self.device)
    
    def init_hidden(self, x):
        h0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).requires_grad_().to(self.device)
        c0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).requires_grad_().to(self.device)
        return h0, c0

# %%
class Classify_Train:
    def __init__(self, model,model_name, optimizer_name, opt_params, batch_size, num_epoch,curr_code, encoder,training_weights):
        
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = model
        #self.loss_fn = loss_fn
        self.history = {'training_loss': [],
                        'test_loss': [],
                        'training_acc': [],
                        'test_acc': [],
                        }

        #Define Optimizer
        lr=opt_params['lr']
        eta=opt_params['eta']
        beta=opt_params['beta']
        r=opt_params['r']
        eps=opt_params['eps']
        weight_decay=opt_params['weight_decay']
        self.batch_size = batch_size
        self.num_epoch = num_epoch
        self.encoder=encoder

        if optimizer_name == 'SGD':
            self.optimizer = optim.SGD(self.model.parameters(), lr=lr)
        elif optimizer_name == 'RMSProp':
            self.optimizer = optim.RMSprop(self.model.parameters(),lr=lr)
        elif optimizer_name == 'ADAM':
            self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        elif optimizer_name == 'AMSGrad':
            self.optimizer = optim.Adam(self.model.parameters(), lr=lr, amsgrad=True)
        elif optimizer_name == 'THEOPOULA':
            self.optimizer = THEOPOULA(self.model.parameters(), lr=lr, eta=eta, beta=beta, r=r, eps=eps,weight_decay=weight_decay)
        #Set Directory Names
        if optimizer_name == 'THEOPOULA':
            self.experiment_name = 'CLX%s_%s_bs{%d}_lr{%.1e}_ech{%d}_eta{%.1e}_beta{%.1e}_r{%d}_eps{%.1e}' \
                      %(optimizer_name, model_name, self.batch_size, lr, self.num_epoch, eta, beta, r, eps)
        else:
            self.experiment_name = 'CLX%s_%s_bs{%d}_lr{%.1e}_eps{%.1e}_ech{%d}'%(optimizer_name, model_name, self.batch_size, lr, eps, self.num_epoch)
        
        log_dir = './log/'
        ckpt_dir = './ckpt/'
        cur_dir = curr_code+'/'
        self.log_dir = log_dir + cur_dir + self.experiment_name
        self.ckpt_dir = ckpt_dir + cur_dir + self.experiment_name
        self.writer = SummaryWriter(log_dir=self.log_dir)

        self.class_weights = (torch.tensor(training_weights,dtype=torch.float)).to(device)
        self.criterion = nn.CrossEntropyLoss(weight=self.class_weights,reduction='mean')
        self.fn_acc = lambda pred, label: torch.sqrt(self.criterion(pred, label))
        self.fn_pred = lambda output: F.log_softmax(output, dim=1).argmax(dim=1)
        
        self.best_loss = 999
        self.best_acc = 0
        self.state = []

    def train(self, epoch,train_loader,  n_features):
        print('\nEpoch: %d' % epoch)
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model.train() # Set Model to Train Mode
        train_loss = []
        acc_arr = []
        total_i, acc_i =0,0
        num_data = len(train_loader)
        num_batch = np.ceil(num_data / self.batch_size)        
        
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs = inputs.view([self.batch_size, -1, n_features]).to(device)
            targets = targets.to(device)
            targets = targets.type(torch.LongTensor) #Change classifiers from Int to LongTensor
            self.optimizer.zero_grad()        
            outputs = self.model(inputs) #Get Logits from Model
            loss = self.criterion(outputs, targets) # Weighted Cross Entropy Loss of Logits vs Target labels
            pred = self.fn_pred(outputs) #Log Softmax of Logits to display predicted label
            
            total_i = targets.size(0)
            correct_i = (pred == targets).sum().item()
            acc_i = correct_i / total_i
            loss.backward()
            self.optimizer.step()
            train_loss += [loss.item()]
            acc_arr += [acc_i]

            if batch_idx%50 == 0:
                print('TRAIN: EPOCH %04d | BATCH %04d/%04d|LOSS: %.4f | Correct %.4f  |total %.4f  |ACC %.4f'%
                (epoch, batch_idx, num_batch, train_loss[-1],correct_i,total_i,np.mean(acc_arr)))

        print('TRAIN: EPOCH %04d| LOSS: %.4f |  ACC %.4f' %
          (epoch, np.mean(train_loss), np.mean(acc_arr)))
        self.writer.add_scalar('Training loss', np.mean(train_loss), epoch)
        self.writer.add_scalar('Training accuracy', np.mean(acc_arr), epoch)

        self.history['training_loss'].append(np.mean(train_loss))
        self.history['training_acc'].append(np.mean(acc_arr))

    def test(self, epoch,test_loader, n_features):
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model.eval() #Set model to evaluate
        test_loss = []
        acc_arr = []
        total_i,acc_i=0,0
        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(test_loader):
                inputs = inputs.view([self.batch_size, -1, n_features]).to(device)
                targets = targets.to(device)
                outputs = self.model(inputs) #Get Logits from Model
                targets = targets.type(torch.LongTensor) #Change classifiers from Int to LongTensor

                loss = self.criterion(outputs, targets) # Weighted Cross Entropy Loss of Logits vs Target labels
                pred = self.fn_pred(outputs)    #Log Softmax of Logits to display predicted label           
                total_i = targets.size(0)
                correct_i = (pred == targets).sum().item()
                acc_i = correct_i / total_i
                test_loss += [loss.item()]
                acc_arr += [acc_i]
               
            print('TEST:  LOSS: %.4f | Correct %.4f  |total %.4f  |  ACC %.4f' %
                    (np.mean(test_loss), correct_i,total_i, np.mean(acc_arr)))

        if np.mean(acc_arr) > self.best_acc:
            print('Saving..')
            self.state = {
                'net': self.model.state_dict(),
                'acc': np.mean(acc_arr),
                'epoch': epoch,
                'optim': self.optimizer.state_dict()
            }
            self.best_loss = np.mean(test_loss)
            self.best_acc = np.mean(acc_arr)
            
        self.writer.add_scalar('Test loss', np.mean(test_loss), epoch)
        self.writer.add_scalar('Test accuracy', np.mean(acc_arr), epoch)

        self.history['test_loss'].append(np.mean(test_loss))
        self.history['test_acc'].append(np.mean(acc_arr))
    
    def activate(self,train_loader, test_loader, n_features):
        #torch.manual_seed(1111)
        start_epoch = 1
        schedule_step=self.num_epoch/2
        scheduler = optim.lr_scheduler.StepLR(self.optimizer, step_size=schedule_step, gamma=0.1)
        for epoch in range(start_epoch, start_epoch + self.num_epoch):
            self.train(epoch, train_loader, n_features)
            self.test(epoch, test_loader, n_features)
            scheduler.step()
        #elapsed_time = time.time() - start_time
        #print(elapsed_time)

        fig, ax = plt.subplots(nrows = 2, ncols = 1)
        ax[0].plot(range(1, self.num_epoch+1), self.history['training_loss'], label='Training Loss')
        ax[0].plot(range(1, self.num_epoch+1), self.history['test_loss'], label='Test Loss')
        ax[0].set_xlabel('Epochs')
        ax[0].set_ylabel('Loss')
        ax[0].legend()
        ax[1].plot(range(1, self.num_epoch+1), self.history['training_acc'], label='Training Accuracy')
        ax[1].plot(range(1, self.num_epoch+1), self.history['test_acc'], label='Test Accuracy')
        ax[1].set_xlabel('Epochs')
        ax[1].set_ylabel('Accuracy')
        ax[1].legend()
        if not os.path.isdir(self.log_dir):
            os.mkdir(self.log_dir)
        pkl.dump(self.history, open(self.log_dir+'/history.pkl', 'wb'))
        #pkl.dump(fig, open(self.log_dir+'/Loss_plot.pkl', 'wb'))

        if not os.path.isdir(self.ckpt_dir):
            os.makedirs(self.ckpt_dir)
        torch.save(self.state, './%s/%s.pth' % (self.ckpt_dir, self.experiment_name))
        plt.show()
    def evaluate(self, test_loader_one,n_features,y_test_indexer):
        self.model.load_state_dict(self.state['net'])
        #self.model.eval() #Set model to evaluate
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        class_names=self.encoder.classes_
        with torch.no_grad():
            predictions = []
            values = []
            probabilities = np.empty((0,len(class_names)), float)

            for x_test, y_test in test_loader_one:
                x_test = x_test.view([1, -1, n_features]).to(device)
                y_test = y_test.to(device)
                self.model.eval()
                out_logits = self.model(x_test)
                yhat = self.fn_pred(out_logits)
                yhat = yhat.to(device).detach().cpu()                
                out_probs = (F.softmax(out_logits , dim=1)).numpy()
                predictions.append(yhat.numpy())                
                values.append(y_test.numpy())
                probabilities = np.append(probabilities, out_probs, axis=0)
        values = np.array(values).astype(int)
        predictions = np.array(predictions).astype(int)
        values = self.encoder.inverse_transform(values)
        predictions = self.encoder.inverse_transform(predictions)        
        probabilities = pd.DataFrame(data=probabilities, columns=class_names,index=y_test_indexer.index[-len(predictions):])
        
        self.df_results = pd.DataFrame({'Predictions':predictions,'Values': values},index=y_test_indexer.index[-len(predictions):])
        self.df_results['Correct'] = np.where((self.df_results['Predictions']==self.df_results['Values']), True, False)        
        self.df_results = self.df_results.merge(probabilities, left_index=True, right_index=True)      
        self.df_results['Crash_sum']= self.df_results['High Crash Confidence']+self.df_results['Low Crash Confidence']+ self.df_results['Medium Crash Confidence']
        self.df_results['Non_Crash_sum']= self.df_results['Large Appreciation']+self.df_results['Small Appreciation']+ self.df_results['Small deppreciation']
        self.df_results['Predicted_prob']=self.df_results[['High Crash Confidence','Medium Crash Confidence','Low Crash Confidence','Small deppreciation','Small Appreciation','Large Appreciation']].max(axis=1)
        idx, cols = pd.factorize(self.df_results['Values'])
        self.df_results['Correct_prob']=self.df_results.reindex(cols, axis=1).to_numpy()[np.arange(len(self.df_results)), idx]
              
        if not os.path.isdir(self.log_dir):
            os.mkdir(self.log_dir)
        pkl.dump(self.df_results.to_dict(), open(self.log_dir+'/results.pkl', 'wb'))        
        
        return self.df_results
    
    def report(self):
        print(classification_report(self.df_results['Values'], self.df_results['Predictions']))
        clx_report = pd.DataFrame(classification_report(self.df_results['Values'], self.df_results['Predictions'],output_dict=True)).transpose()
        if not os.path.isdir(self.log_dir):
            os.mkdir(self.log_dir)
        pkl.dump(clx_report.to_dict(), open(self.log_dir+'/report.pkl', 'wb'))   
        return clx_report

# %%
'''

import torch.optim as optim
class_net=LSTMClassifier(input_dim, hidden_dim, layer_dim, 6)
class_trial = Classify_Train(class_net,'LSTMClx', 'THEOPOULA', optimiser_params, batch_size,400 ,currency_code, enc, class_weights)
class_trial.activate(train_loader, test_loader, input_dim)


results=class_trial.evaluate(test_loader_one, input_dim,y_test_arr)
'''

# %% [markdown]
# ### Theopoula

# %%
THEOPOULA_net = LSTMClassifier(input_dim, hidden_dim, layer_dim, output_dim)
class_trial = Classify_Train(THEOPOULA_net,'LSTMClx', 'THEOPOULA', optimiser_params, batch_size,num_epoch ,currency_code, enc, class_weights)#
class_trial.activate(train_loader, test_loader, input_dim)

THEOPOULA_results=class_trial.evaluate(test_loader_one, input_dim,y_test_arr)
THEOPOULA_report = class_trial.report()
# Out:
# Epoch: 1
# TRAIN: EPOCH 0001 | BATCH 0000/0005|LOSS: 1.8180 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0001 | BATCH 0050/0005|LOSS: 1.7695 | Correct 3.0000  |total 32.0000  |ACC 0.1477
# TRAIN: EPOCH 0001 | BATCH 0100/0005|LOSS: 1.5828 | Correct 25.0000  |total 32.0000  |ACC 0.1584
# TRAIN: EPOCH 0001| LOSS: 1.8646 |  ACC 0.1554
# TEST:  LOSS: 1.9426 | Correct 4.0000  |total 32.0000  |  ACC 0.0809
# Saving..
#
# Epoch: 2
# TRAIN: EPOCH 0002 | BATCH 0000/0005|LOSS: 1.8181 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0002 | BATCH 0050/0005|LOSS: 1.7692 | Correct 3.0000  |total 32.0000  |ACC 0.1477
# TRAIN: EPOCH 0002 | BATCH 0100/0005|LOSS: 1.5827 | Correct 25.0000  |total 32.0000  |ACC 0.1584
# TRAIN: EPOCH 0002| LOSS: 1.8643 |  ACC 0.1554
# TEST:  LOSS: 1.9423 | Correct 4.0000  |total 32.0000  |  ACC 0.0809
#
# Epoch: 3
# TRAIN: EPOCH 0003 | BATCH 0000/0005|LOSS: 1.8183 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# ...

# %%
prob_plot(THEOPOULA_results)

# %%
THEOPOULA_report
# Out:
#                          precision    recall  f1-score      support
# Large Appreciation        0.098566  1.000000  0.179445   110.000000
# Low Crash Confidence      0.000000  0.000000  0.000000   133.000000
# Medium Crash Confidence   0.000000  0.000000  0.000000     1.000000
# Small Appreciation        0.000000  0.000000  0.000000   443.000000
# Small deppreciation       0.000000  0.000000  0.000000   429.000000
# accuracy                  0.098566  0.098566  0.098566     0.098566
# macro avg                 0.019713  0.200000  0.035889  1116.000000
# weighted avg              0.009715  0.098566  0.017687  1116.000000

# %% [markdown]
# ### ADAM

# %%
ADAM_net = LSTMClassifier(input_dim, hidden_dim, layer_dim, output_dim)
class_trial = Classify_Train(ADAM_net,'LSTMClx', 'ADAM', optimiser_params, batch_size,num_epoch ,currency_code, enc, class_weights)#
class_trial.activate(train_loader, test_loader, input_dim)

ADAM_results=class_trial.evaluate(test_loader_one, input_dim,y_test_arr)
ADAM_report = class_trial.report()
# Out:
# Epoch: 1
# TRAIN: EPOCH 0001 | BATCH 0000/0005|LOSS: 1.9574 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0001 | BATCH 0050/0005|LOSS: 1.6652 | Correct 11.0000  |total 32.0000  |ACC 0.2138
# TRAIN: EPOCH 0001 | BATCH 0100/0005|LOSS: 1.4156 | Correct 25.0000  |total 32.0000  |ACC 0.2157
# TRAIN: EPOCH 0001| LOSS: 1.8073 |  ACC 0.1947
# TEST:  LOSS: 1.8432 | Correct 4.0000  |total 32.0000  |  ACC 0.0809
# Saving..
#
# Epoch: 2
# TRAIN: EPOCH 0002 | BATCH 0000/0005|LOSS: 1.9570 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0002 | BATCH 0050/0005|LOSS: 1.6624 | Correct 11.0000  |total 32.0000  |ACC 0.2138
# TRAIN: EPOCH 0002 | BATCH 0100/0005|LOSS: 1.4154 | Correct 25.0000  |total 32.0000  |ACC 0.2157
# TRAIN: EPOCH 0002| LOSS: 1.8038 |  ACC 0.1947
# TEST:  LOSS: 1.8380 | Correct 4.0000  |total 32.0000  |  ACC 0.0809
#
# Epoch: 3
# TRAIN: EPOCH 0003 | BATCH 0000/0005|LOSS: 1.9566 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# ...

# %%
prob_plot(ADAM_results)

# %%
ADAM_report
# Out:
#                          precision    recall  f1-score      support
# Large Appreciation        0.000000  0.000000  0.000000   110.000000
# Low Crash Confidence      0.000000  0.000000  0.000000   133.000000
# Medium Crash Confidence   0.000000  0.000000  0.000000     1.000000
# Small Appreciation        0.396953  1.000000  0.568313   443.000000
# Small deppreciation       0.000000  0.000000  0.000000   429.000000
# accuracy                  0.396953  0.396953  0.396953     0.396953
# macro avg                 0.079391  0.200000  0.113663  1116.000000
# weighted avg              0.157572  0.396953  0.225594  1116.000000

# %% [markdown]
# ### AMSGrad

# %%
AMSGrad_net = LSTMClassifier(input_dim, hidden_dim, layer_dim, output_dim)
class_trial = Classify_Train(AMSGrad_net,'LSTMClx', 'AMSGrad', optimiser_params, batch_size,num_epoch ,currency_code, enc, class_weights)#
class_trial.activate(train_loader, test_loader, input_dim)

AMSGrad_results=class_trial.evaluate(test_loader_one, input_dim,y_test_arr)
AMSGrad_report = class_trial.report()
# Out:
# Epoch: 1
# TRAIN: EPOCH 0001 | BATCH 0000/0005|LOSS: 1.6374 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0001 | BATCH 0050/0005|LOSS: 1.6818 | Correct 11.0000  |total 32.0000  |ACC 0.2138
# TRAIN: EPOCH 0001 | BATCH 0100/0005|LOSS: 1.5317 | Correct 25.0000  |total 32.0000  |ACC 0.2157
# TRAIN: EPOCH 0001| LOSS: 1.7790 |  ACC 0.1947
# TEST:  LOSS: 1.8253 | Correct 4.0000  |total 32.0000  |  ACC 0.0809
# Saving..
#
# Epoch: 2
# TRAIN: EPOCH 0002 | BATCH 0000/0005|LOSS: 1.6391 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0002 | BATCH 0050/0005|LOSS: 1.6805 | Correct 11.0000  |total 32.0000  |ACC 0.2138
# TRAIN: EPOCH 0002 | BATCH 0100/0005|LOSS: 1.5305 | Correct 25.0000  |total 32.0000  |ACC 0.2157
# TRAIN: EPOCH 0002| LOSS: 1.7778 |  ACC 0.1947
# TEST:  LOSS: 1.8238 | Correct 4.0000  |total 32.0000  |  ACC 0.0809
#
# Epoch: 3
# TRAIN: EPOCH 0003 | BATCH 0000/0005|LOSS: 1.6409 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# ...

# %%
AMSGrad_report
# Out:
#                          precision    recall  f1-score      support
# Large Appreciation        0.130790  0.436364  0.201258   110.000000
# Low Crash Confidence      0.000000  0.000000  0.000000   133.000000
# Medium Crash Confidence   0.000000  0.000000  0.000000     1.000000
# Small Appreciation        0.428771  0.693002  0.529767   443.000000
# Small deppreciation       0.393939  0.030303  0.056277   429.000000
# accuracy                  0.329749  0.329749  0.329749     0.329749
# macro avg                 0.190700  0.231934  0.157460  1116.000000
# weighted avg              0.334527  0.329749  0.251763  1116.000000

# %%
prob_plot(AMSGrad_results)

# %% [markdown]
# ### RMSProp

# %%
RMSProp_net = LSTMClassifier(input_dim, hidden_dim, layer_dim, output_dim)
class_trial = Classify_Train(RMSProp_net,'LSTMClx', 'RMSProp', optimiser_params, batch_size,num_epoch ,currency_code, enc, class_weights)#
class_trial.activate(train_loader, test_loader, input_dim)

RMSProp_results=class_trial.evaluate(test_loader_one, input_dim,y_test_arr)
RMSProp_report = class_trial.report()
# Out:
# Epoch: 1
# TRAIN: EPOCH 0001 | BATCH 0000/0005|LOSS: 1.9642 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0001 | BATCH 0050/0005|LOSS: 1.8183 | Correct 14.0000  |total 32.0000  |ACC 0.1183
# TRAIN: EPOCH 0001 | BATCH 0100/0005|LOSS: 1.9644 | Correct 0.0000  |total 32.0000  |ACC 0.1148
# TRAIN: EPOCH 0001| LOSS: 1.8384 |  ACC 0.0793
# TEST:  LOSS: 1.8198 | Correct 28.0000  |total 32.0000  |  ACC 0.2619
# Saving..
#
# Epoch: 2
# TRAIN: EPOCH 0002 | BATCH 0000/0005|LOSS: 1.9625 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0002 | BATCH 0050/0005|LOSS: 1.8097 | Correct 14.0000  |total 32.0000  |ACC 0.1207
# TRAIN: EPOCH 0002 | BATCH 0100/0005|LOSS: 1.9574 | Correct 3.0000  |total 32.0000  |ACC 0.1191
# TRAIN: EPOCH 0002| LOSS: 1.8329 |  ACC 0.0829
# TEST:  LOSS: 1.8160 | Correct 28.0000  |total 32.0000  |  ACC 0.2858
# Saving..
#
# Epoch: 3
# TRAIN: EPOCH 0003 | BATCH 0000/0005|LOSS: 1.9619 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# ...

# %%
RMSProp_report
# Out:
#                    Predictions              Values  Correct  \
# Date
# 2016-01-14  Small Appreciation  Small Appreciation     True
# 2016-01-15  Small Appreciation  Small Appreciation     True
# 2016-01-19  Small Appreciation  Small Appreciation     True
# 2016-01-20  Small Appreciation  Small Appreciation     True
# 2016-01-21  Small Appreciation  Small Appreciation     True
# ...                        ...                 ...      ...
# 2020-06-24  Small Appreciation  Large Appreciation    False
# 2020-06-25  Small Appreciation  Large Appreciation    False
# 2020-06-26  Small Appreciation  Large Appreciation    False
# 2020-06-29  Small Appreciation  Large Appreciation    False
# 2020-06-30  Small Appreciation  Large Appreciation    False
#
#             High Crash Confidence  Large Appreciation  Low Crash Confidence  \
# Date
# 2016-01-14               0.037869            0.241344              0.120621
# 2016-01-15               0.037823            0.241435              0.120656
# ...

# %%
prob_plot(RMSProp_results)

# %%
RMSProp_report.to_clipboard()

# %% [markdown]
# ### Plot all optimisers

# %%
optim_plot(currency_code)
# Out:
# AMSGrad:  test_loss - 1.5626002059263342
# ADAM:  test_loss - 1.4514108300209045
# RMSprop:  test_loss - 1.4938974029877607
# THEOPOULA:  test_loss - 1.8765232282526352

# %%
dataset_to_plot = results.copy()
labels = ['High Crash Confidence','Medium Crash Confidence','Low Crash Confidence','Small deppreciation','Small Appreciation','Large Appreciation']

#melt_probs = pd.melt(dataset_to_plot[['High Crash Confidence','Medium Crash Confidence','Low Crash Confidence','Small deppreciation','Large Appreciation']].reset_index(),
#                    value_vars=['High Crash Confidence','Medium Crash Confidence','Low Crash Confidence','Small deppreciation','Large Appreciation'],
#                    id_vars = 'Date', var_name = 'Classification', value_name='Probabilities')
#melt_probs.sort_values(by=['Date', 'Classification'], inplace=True)


col_pallet = ['#f20000','#da00f2','#3000f2','#0089f2','#00f2c5','#04f200']
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize=(16,4))

ax[0].stackplot(x_dates,dataset_to_plot['High Crash Confidence'].tolist(),
             dataset_to_plot['Medium Crash Confidence'].tolist(),
             dataset_to_plot['Low Crash Confidence'].tolist(),
             dataset_to_plot['Small deppreciation'].tolist(),
             dataset_to_plot['Small Appreciation'].tolist(),
             dataset_to_plot['Large Appreciation'].tolist(),
             labels=labels,colors=col_pallet)
ax[0].set_xlabel('Time')
ax[0].tick_params(axis='x', rotation=45)
ax[0].set_ylabel('Probabilities')
#ax[0].legend()
ax[1].plot(dataset_to_plot.index, dataset_to_plot['Predicted_prob'], label='Probability of Predicted Classification')
ax[1].plot(dataset_to_plot.index, dataset_to_plot['Correct_prob'], label='Probability of Correct Classification ')
#ax[1].legend(loc='upper right')
ax[1].tick_params(axis='x', rotation=45)
#fig.suptitle('Probability visualisation: Model Resulting Probabilities Predictions', fontsize=15)
h1, l1 = ax[0].get_legend_handles_labels()
h2, l2 = ax[1].get_legend_handles_labels()
fig.legend(h1, l1, loc='upper left', ncol=2, fontsize=9)
fig.legend(h2, l2, loc='upper right', ncol=1, fontsize=9)
#sns.kdeplot(data=melt_probs, x="Date", y='Probabilities',hue="Classification",cumulative=True, common_norm=False, common_grid=True,ax=ax)

# %%
def multi_probs_plot(cur_code):
    import FX_DATA_GEN as DG
    
    cntry = DG.Get_country_name(cur_code)
    path = './log/%s/CLXAMSGrad_LSTMClx_bs{32}_lr{1.0e-05}_eps{1.0e-03}_ech{400}/results.pkl'% (cur_code)
    df_amsgrad = pkl.load(open(path, 'rb'))
    df_amsgrad = pd.DataFrame(df_amsgrad)
    
    path = './log/%s/CLXADAM_LSTMClx_bs{32}_lr{1.0e-05}_eps{1.0e-03}_ech{400}/results.pkl'% (cur_code)
    df_adam = pkl.load(open(path, 'rb'))
    df_adam = pd.DataFrame(df_adam)
    
    path = './log/%s/CLXRMSProp_LSTMClx_bs{32}_lr{1.0e-05}_eps{1.0e-03}_ech{400}/results.pkl'% (cur_code)
    df_rms = pkl.load(open(path, 'rb'))
    df_rms = pd.DataFrame(df_rms)
    
    path = './log/%s/CLXTHEOPOULA_LSTMClx_bs{32}_lr{1.0e-05}_ech{400}_eta{0.0e+00}_beta{1.0e+15}_r{0}_eps{1.0e-03}/results.pkl'% (cur_code)
    df_theopoula = pkl.load(open(path, 'rb'))    
    df_theopoula = pd.DataFrame(df_theopoula)
    
    dataframes = [df_amsgrad, df_adam, df_rms, df_theopoula]
    optimisers = ['AMSGrad', 'ADAM', 'RMSProp', 'THEO_POULA']
    # Prepare for plotting 
    labels = ['High Crash Confidence','Medium Crash Confidence','Low Crash Confidence','Small deppreciation','Small Appreciation','Large Appreciation']
    col_pallet = ['#f20000','#da00f2','#3000f2','#0089f2','#00f2c5','#04f200']
    fig, ax = plt.subplots(nrows = len(dataframes), ncols = 2, figsize=(20,12))
    for i in range(len(dataframes)):
        dataset_to_plot = dataframes[i].copy()
        ax[0,0].set_title('Probability results of all classifications ')
        ax[0,1].set_title('Probability of Correct classification vs Predicted classification')
        ax[i,0].stackplot(dataset_to_plot.index,dataset_to_plot['High Crash Confidence'].tolist(),
                     dataset_to_plot['Medium Crash Confidence'].tolist(),
                     dataset_to_plot['Low Crash Confidence'].tolist(),
                     dataset_to_plot['Small deppreciation'].tolist(),
                     dataset_to_plot['Small Appreciation'].tolist(),
                     dataset_to_plot['Large Appreciation'].tolist(),
                     labels=labels,colors=col_pallet)
        ax[i,0].set_xlabel('Time')
        ax[i,0].tick_params(axis='x', rotation=45)
        ax[i,0].set_ylabel(f'{optimisers[i]}:All Probabilities', rotation = 90)
        ax[i,1].plot(dataset_to_plot.index, dataset_to_plot['Predicted_prob'], label='Probability of Predicted Classification')
        ax[i,1].plot(dataset_to_plot.index, dataset_to_plot['Correct_prob'], label='Probability of Correct Classification ')
        ax[i,1].tick_params(axis='x', rotation=45)
        ax[i,1].set_ylabel(f'{optimisers[i]}: Probability', rotation = 90)
    fig.suptitle(f'{cntry}:Probability visualisation: Model Resulting Probabilities Predictions', fontsize=15)
    h1, l1 = ax[i,0].get_legend_handles_labels()
    h2, l2 = ax[i,1].get_legend_handles_labels()
    fig.legend(h1+h2, l1+h2, loc='lower center', ncol=3, fontsize=9)

# %%
DG.Get_country_name(currency_code)
# Out:
# 'South Korea'

# %%
multi_probs_plot(currency_code)

# %%
melt_compare = pd.melt(results[['Predictions','Values','Correct','Predicted_prob','Correct_prob']].reset_index(),#
                        value_vars=['Predicted_prob','Correct_prob'],
                        id_vars = ['Date','Predictions','Values','Correct'], var_name = 'Probability_class', value_name='Probabilities').sort_values(by=['Date'])
melt_compare

#sns.scatterplot(data=melt_compare, x="Date", y="Probabilities",style='Probability_class', hue="Values")
#sns.lineplot(data=results, x=results.index, y=, hue="month", style="month")

fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(14,6))

ax.plot(results.index, results['Predicted_prob'], label='Probability of Predicted Classification')
ax.plot(results.index, results['Correct_prob'], label='Probability of Correct Classification ')
ax.legend()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(14,6))
#plt.plot(X_train.index, X_train.iloc[:,0], label='Values - Training Set')
#plt.plot(X_val.index, X_val.iloc[:,0], label='Values - Validation Set')
ax.plot(X_test.index, X_test.iloc[:,0], label='Values - Test Set')
twinax = ax.twinx()
twinax.plot(results.index, results['Crash_sum'],label='Crash Probabilities', linestyle='--')
twinax.plot(results.index, results['Non_Crash_sum'],label='Crash Probabilities', linestyle='--')
ax.set_xlabel('Time')
ax.set_ylabel('FX Rate')
twinax.set_ylabel('Probabilities')
ax.legend()
twinax.legend()

# %%
from sklearn.metrics import classification_report
print(classification_report(df_results['Values'], df_results['Predictions']))
# Out:
#                       precision    recall  f1-score   support
#
#   Large Appreciation       0.03      1.00      0.06        36
# Low Crash Confidence       0.14      0.37      0.20       205
#   Small Appreciation       0.00      0.00      0.00      1039
#  Small deppreciation       0.28      0.10      0.15       567
#
#             accuracy                           0.09      1847
#            macro avg       0.11      0.37      0.10      1847
#         weighted avg       0.10      0.09      0.07      1847
# C:\Users\S1026623\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# ## ADAM Classifier

# %%
import torch.optim as optim
ADAM_CLX_net=LSTMClassifier(input_dim, hidden_dim, layer_dim, 6)

ADAM_CLX = Classify_Train(ADAM_CLX_net,'LSTMClx', 'ADAM', optimiser_params, batch_size, 300 ,currency_code, enc, class_weights)
ADAM_CLX.activate(train_loader, test_loader, input_dim)

ADAM_results=ADAM_CLX.evaluate(test_loader_one, input_dim,y_test_arr)
ADAM_results['Crash_sum']= ADAM_results['High Crash Confidence']+ADAM_results['Low Crash Confidence']+ ADAM_results['Medium Crash Confidence']
ADAM_results['Non_Crash_sum']= ADAM_results['Large Appreciation']+ADAM_results['Small Appreciation']+ ADAM_results['Small deppreciation']
# Out:
# Epoch: 1
# TRAIN: EPOCH 0001 | BATCH 0000/0008|LOSS: 1.9645 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0001 | BATCH 0050/0008|LOSS: 1.8767 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0001 | BATCH 0100/0008|LOSS: 1.7863 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0001 | BATCH 0150/0008|LOSS: 1.9575 | Correct 0.0000  |total 32.0000  |ACC 0.0319
# TRAIN: EPOCH 0001 | BATCH 0200/0008|LOSS: 2.0928 | Correct 12.0000  |total 32.0000  |ACC 0.0533
# TRAIN: EPOCH 0001| LOSS: 1.8353 |  ACC 0.0626
# TEST:  LOSS: 1.8342 | Correct 8.0000  |total 32.0000  |  ACC 0.1327
# Saving..
#
# Epoch: 2
# TRAIN: EPOCH 0002 | BATCH 0000/0008|LOSS: 1.9575 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0002 | BATCH 0050/0008|LOSS: 1.8697 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# TRAIN: EPOCH 0002 | BATCH 0100/0008|LOSS: 1.7760 | Correct 0.0000  |total 32.0000  |ACC 0.0000
# ...

# %%
ADAM_CLX.report()
# Out:
#                       precision    recall  f1-score   support
#
#   Large Appreciation       0.00      0.00      0.00        36
# Low Crash Confidence       0.00      0.00      0.00       205
#   Small Appreciation       0.56      1.00      0.72      1039
#  Small deppreciation       0.00      0.00      0.00       567
#
#             accuracy                           0.56      1847
#            macro avg       0.14      0.25      0.18      1847
#         weighted avg       0.32      0.56      0.41      1847
# C:\Users\S1026623\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
#ytest=pd.DataFrame(y_test)
#ytest[ytest[0]!=3]
print(df_results.loc['2020-02-14'])
# Out:
# Predictions      n/a
# Values           Low
# Correct        False
# Name: 2020-02-14 00:00:00, dtype: object

# %%
#from sklearn.utils.class_weight import compute_class_weight
enc.classes_
#weights=compute_class_weight('balanced',[0,1,2,3],y_test)
print(torch.tensor(class_weights,dtype=torch.float))
print(torch.tensor(class_weights,dtype=torch.float))
# Out:
# tensor([3.5214, 2.3404, 8.4051, 0.3155])
# tensor([12.4003,  5.4777, 70.6459,  0.0995])

# %%
class_trial.history

# %%
from sklearn.metrics import classification_report
print(classification_report(df_results['Values'], df_results['Predictions']))
#print('Correct predictions:',(df_results['Predictions']==df_results['Values']).sum())
#print('Out Of :',(df_results['Predictions'].shape[0]))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.00      0.00      0.00        76
#          Low       0.00      0.00      0.00       400
#       Medium       0.00      0.00      0.00       129
#          n/a       0.67      1.00      0.81      1250
#
#     accuracy                           0.67      1855
#    macro avg       0.17      0.25      0.20      1855
# weighted avg       0.45      0.67      0.54      1855
# C:\Users\S1026623\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# ## Run Various Models

# %% [raw]
# df_results.groupby(['Values','Predictions','Correct']).agg(Correct_Classifications=('Correct', 'count')).reset_index()

# %% [markdown]
# ### TheoPoula

# %%
TPmodel = get_model(model_name, model_params)
TP_eval = THEO_POULA_TRAIN(TPmodel,
                          'lstm', 
                          'THEOPOULA', 
                          optimiser_params,
                           batch_size,
                           num_epoch,
                          currency_code)
TP_eval.activate(train_loader, test_loader, input_dim)

# %%
predictions, values = TP_eval.evaluate(test_loader_one, input_dim)

# %%
df_results = pd.DataFrame(hstack((predictions, values)),columns = ['Predictions', 'Values'],index=y_test_arr.index[-len(predictions):])
df_results.tail(10)
# Out:
#             Predictions  Values
# Date
# 2020-09-30     0.047208     0.0
# 2020-10-01     0.043421     0.0
# 2020-10-02     0.043324     0.0
# 2020-10-05     0.043408     0.0
# 2020-10-06     0.043415     0.0
# 2020-10-07     0.043439     0.0
# 2020-10-08     0.043503     0.0
# 2020-10-09     0.043626     0.0
# 2020-10-13     0.043580     0.0
# 2020-10-14     0.043607     0.0

# %% [markdown]
# ### ADAM

# %%
ADAMmodel = get_model(model_name, model_params)
ADAM_eval = THEO_POULA_TRAIN(ADAMmodel,
                          'lstm', 
                          'ADAM', 
                          optimiser_params,
                           batch_size,
                           num_epoch,
                          currency_code)
ADAM_eval.activate(train_loader, test_loader, input_dim)

# %%
pd.to_datetime(df_results.index)
# Out:
# DatetimeIndex(['2016-09-21', '2016-09-22', '2016-09-23', '2016-09-26',
#                '2016-09-27', '2016-09-28', '2016-09-29', '2016-09-30',
#                '2016-10-03', '2016-10-04',
#                ...
#                '2020-09-30', '2020-10-01', '2020-10-02', '2020-10-05',
#                '2020-10-06', '2020-10-07', '2020-10-08', '2020-10-09',
#                '2020-10-13', '2020-10-14'],
#               dtype='datetime64[ns]', name='Date', length=1015, freq=None)

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(14,6))

#ax[0].plot(X_train.index, X_train.iloc[:,0], label='Values - Training Set', color='#0000ff')
#ax[0].plot(y_train.index, y_train.iloc[:], label='Values - Training Set', color='#0000ff')
ax.plot(pd.to_datetime(df_results.index), df_results['Predictions'], label='Predictions', linestyle = '--',color='#00bf00' )
ax.plot(pd.to_datetime(df_results.index), df_results['Values'], label='Values - Test Set', color='#ff0000')
ax.tick_params(axis='x', rotation=45)
ax.set_xlabel('Time')
ax.set_ylabel('Indicator')
ax.legend()
ax.set_title('Results with full training data for context')
ax0 = ax.twinx()
ax0.plot(pd.to_datetime(ind_5.index[-len(predictions):]), ind_5.iloc[-len(predictions):,0], label='FX Rate', linestyle = '--',color='#0000ff') #FX Rate 
ax0.set_ylabel(f'{currency_code} Domestic Currency per 1 US Dollar ')
ax0.legend(['FX Rate to USD'], loc = 'upper right')

fig.suptitle('30day FX Rate Average - Predictions vs real values', fontsize=15)
# Out:
# Text(0.5, 0.98, '30day FX Rate Average - Predictions vs real values')

# %%
ADAM_eval.history

# %%
RSMmodel = get_model(model_name, model_params)
RSM_eval = THEO_POULA_TRAIN(RSMmodel,
                          'lstm', 
                          'RMSProp', 
                          optimiser_params,
                           batch_size,
                           num_epoch,
                          currency_code)
RSM_eval.activate(train_loader, test_loader, input_dim)

# %%
AMSGradmodel = get_model(model_name, model_params)
AMSGrad_eval = THEO_POULA_TRAIN(AMSGradmodel,
                          'lstm', 
                          'AMSGrad', 
                          optimiser_params,
                           batch_size,
                           num_epoch,
                          currency_code)
AMSGrad_eval.activate(train_loader, test_loader, input_dim)

# %% [markdown]
# ## Trian & Test Model

# %%
path = './log/MXN/THEOPOULA_lstm_bs{32}_lr{1.0e-03}_epoch{400}_eta{0.0e+00}_beta{1.0e+15}_r{0}_eps{1.0e-04}/history.pkl'
df_theopoula = pkl.load(open(path, 'rb'))

path = './log/MXN/ADAM_lstm_bs{32}_lr{1.0e-03}_eps{1.0e-04}_epoch{400}/history.pkl'
df_adam = pkl.load(open(path, 'rb'))

Plot_num = pd.DataFrame(df_adam).shape[1]

fig, ax = plt.subplots(nrows = 4, ncols = 1, figsize=(9,10))
for i, key in zip(range(1, 5), class_trial.history.keys()):
    #ax[i-1].plot(df_amsgrad[key], label='AMSGRAD')
    ax[i-1].plot(ADAM_CLX.history[key], label='ADAM')
    #ax[i-1].plot(df_rms[key], label='RMSProp')
    ax[i-1].plot(class_trial.history[key], label='TheoPouLa')
    ax[i-1].legend()
    ax[i-1].set_title(key)
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3c305541e2a3> in <module>
#       8
#       9 fig, ax = plt.subplots(nrows = 4, ncols = 1, figsize=(9,10))
# ---> 10 for i, key in zip(range(1, 5), class_trial.history.keys()):
#      11     #ax[i-1].plot(df_amsgrad[key], label='AMSGRAD')
#      12     ax[i-1].plot(ADAM_CLX.history[key], label='ADAM')
#
# NameError: name 'class_trial' is not defined

# %%
history['training_loss']
# Out:
# 88.63677266064812

# %%
def evaluate(test_loader, batch_size, n_features, model):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    with torch.no_grad():
        predictions = []
        values = []
        for x_test, y_test in test_loader:
            x_test = x_test.view([batch_size, -1, n_features]).to(device)
            y_test = y_test.to(device)
            model.eval()
            yhat = model(x_test)
            yhat = torch.flatten(yhat).detach().cpu()
            predictions.append(yhat.numpy())
            y_test=y_test.to(device).detach().cpu()
            values.append(y_test.numpy())
    return predictions, values

# %%
predictions, values =  evaluate(test_loader_one, batch_size=1, n_features=input_dim, model=model)

# %%
df_results = pd.DataFrame(hstack((predictions, values)),columns = ['Predictions', 'Values'],index=y_test_arr.index[-len(predictions):])
pkl.dump(df_results.to_dict(), open(log_dir+'/val_results.pkl', 'wb'))
df_results
# Out:
#             Predictions     Values
# Date
# 2016-08-09    18.058687  18.695221
# 2016-08-10    18.032301  18.735353
# 2016-08-11    18.005610  18.784420
# 2016-08-12    17.982347  18.838104
# 2016-08-15    17.952902  18.885437
# ...                 ...        ...
# 2020-10-07    17.488712  20.888054
# 2020-10-08    17.476362  20.844486
# 2020-10-09    17.461374  20.806454
# 2020-10-13    17.454506  20.760553
# 2020-10-14    17.446154  20.720686
#
# [1045 rows x 2 columns]

# %% [markdown]
# ## Results Plotting

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize=(14,6))


#ax[0].plot(X_train.index, X_train.iloc[:,0], label='Values - Training Set', color='#0000ff')
ax[0].plot(y_train.index, y_train.iloc[:], label='Values - Training Set', color='#0000ff')
ax[0].plot(y_test.index[-len(predictions):], array(predictions), label='Predictions', linestyle = '--',color='#00bf00' )
ax[0].plot(y_test.index, y_test.iloc[:], label='Values - Test Set', color='#ff0000')
ax[0].tick_params(axis='x', rotation=45)
ax[0].set_xlabel('Time')
ax[0].set_ylabel('FX Rate - 30 day average')
ax[0].legend()
ax[0].set_title('Results with full training data for context')
ax[1].plot(y_test.index[-len(predictions):], array(predictions), label='Predictions', linestyle = '--',color='#00bf00' )
ax[1].plot(y_test.index, y_test.iloc[:], label='Values - Test Set', color='#ff0000')
ax[1].set_xlabel('Time')
ax[1].tick_params(axis='x', rotation=45)
ax[1].set_ylabel('FX Rate - 30 day average')
ax[1].legend()
ax[1].set_title('Results over Test Period')
fig.suptitle('30day FX Rate Average - Predictions vs real values', fontsize=15)
# Out:
# Text(0.5, 0.98, '30day FX Rate Average - Predictions vs real values')

# %%
Test_set = pd.merge(cloned_data, df_results, right_index = True, left_index=True, how='right')

ave30 = currency_code+'_30_ave'
pred30 = currency_code+'_30_pred'

Test_set['Class_value(%)'] = 100*(Test_set[pred30] -Test_set[ave30].shift(60))/Test_set[ave30].shift(60)
Test_set['Class_pred(%)'] = 100*(Test_set['Predictions'] -Test_set[ave30].shift(60))/Test_set[ave30].shift(60)
cut_labels = ['normal behaviour', 'Low', 'Medium', 'High']
cuts = [float('-inf'),5,10,15,float('inf')]
Test_set['Class(real)'] = pd.cut(Test_set['Class_value(%)'],bins=cuts,labels=cut_labels)
Test_set['Class(pred)'] = pd.cut(Test_set['Class_pred(%)'],bins=cuts,labels=cut_labels)


l1 = 5.0
l2 = 10.0
l3 = 15.0
l1_arr = np.full(shape=len(Test_set['Class_value(%)']),fill_value = l1)
l2_arr = np.full(shape=len(Test_set['Class_value(%)']),fill_value = l2)
l3_arr = np.full(shape=len(Test_set['Class_value(%)']),fill_value = l3)

fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(14,6))
ax.plot(Test_set.index, Test_set['Class_pred(%)'], label='Predictions - FX Rate change',color='#00bf00')
ax.plot(Test_set.index, Test_set['Class_value(%)'], label='Values - FX Rate change',color='#ff0000')
ax.plot([Test_set.index.min(),Test_set.index.max()], [l1,l1],color='#ffff63',linestyle = '--' ,  linewidth= 0.5, label = '5% drop') #low yelloe='#ffff63'
ax.plot([Test_set.index.min(),Test_set.index.max()], [l2,l2],color='#ff8d23',linestyle = '--' ,  linewidth= 0.5, label = '10% drop') #med
ax.plot([Test_set.index.min(),Test_set.index.max()], [l3,l3],color='#ff00ff',linestyle = '--' , linewidth= 0.5, label = '15% drop') #high

ax.fill_between(Test_set.index,Test_set['Class_value(%)'], where=(0 < Test_set['Class_value(%)']), color='#999999', alpha = 0.3)
ax.fill_between(Test_set.index,Test_set['Class_value(%)'], where=(l1 < Test_set['Class_value(%)']), color='#ffff63')
ax.fill_between(Test_set.index,Test_set['Class_value(%)'], where=(l2 <Test_set['Class_value(%)']), color='#ff8d23')
ax.fill_between(Test_set.index,Test_set['Class_value(%)'], where=(l3 <Test_set['Class_value(%)']), color='#ff00ff')

#ax.fill_between(Test_set.index,Test_set['Class_pred(%)'], where=(l1 < Test_set['Class_pred(%)']), color='#ffff63')
#ax.fill_between(Test_set.index,Test_set['Class_pred(%)'], where=(l2 <Test_set['Class_pred(%)']), color='#ff8d23')
#ax.fill_between(Test_set.index,Test_set['Class_pred(%)'], where=(l3 <Test_set['Class_pred(%)']), color='#ff00ff')

ax.set_xlabel('3mth Rate of FX Rate change')
ax.set_ylabel('Time')
ax.set_title(f'{currency_code} 3mth Change in FX Rate')
#ax.set_xticks(rotation = 45)
ax.legend()
pkl.dump(Test_set.to_dict(), open(log_dir+'/cln_results.pkl', 'wb'))

# %%
Tablueated_class = pd.melt(Test_set[['Class(real)', 'Class(pred)']], var_name='Data', value_name='Classification').groupby(['Data', 'Classification']).agg(Count=('Data', 'count')).reset_index()
Tablueated_class = pd.pivot_table(Tablueated_class, values='Count', index=['Data'],columns=['Classification'], aggfunc=np.sum).fillna(0).reset_index()
Tablueated_class = Tablueated_class.reindex(columns = ['Data','normal behaviour','Low','Medium','High'])
pkl.dump(Tablueated_class.to_dict(), open(log_dir+'/cln_count.pkl', 'wb'))
Tablueated_class
# Out:
# Classification         Data  normal behaviour    Low  Medium  High
# 0               Class(pred)             985.0    NaN     NaN   NaN
# 1               Class(real)             724.0  139.0    46.0  76.0

# %%
#Test_set['Correct Classification'] = np.where(Test_set['Class(pred)']==Test_set['Class(real)'],1,0)

Acc = Test_set[['Correct Classification','Class(real)']].groupby(['Class(real)']).agg(Correct_Classifications=('Correct Classification', 'sum'), Total_count=('Correct Classification', 'count')).reset_index()
Acc
# Out:
#         Class(real)  Correct_Classifications  Total_count
# 0  normal behaviour                      724          724
# 1               Low                        0          139
# 2            Medium                        0           46
# 3              High                        0           76

# %%
def inverse_transform(scaler, df, columns):
    for col in columns:
        df[col] = scaler.inverse_transform(df[col])
    return df

def format_predictions(predictions, values, df_test, scaler):
    vals = np.concatenate(values, axis=0).ravel()
    preds = np.concatenate(predictions, axis=0).ravel()
    df_result = pd.DataFrame(data={"value": vals, "prediction": preds}, index=df_test.head(len(vals)).index)
    df_result = df_result.sort_index()
    df_result["prediction"] = inverse_transform(scaler, df_result, [["prediction"]])
    return df_result

# %%
df_result = format_predictions(predictions, values, X_test, scaler)
df_result

# %%
predictions_full, values_full = evaluate(test_loader, batch_size=batch_size, n_features=input_dim, model=model)

# %% [markdown]
# ## Optimizer comparisons

# %%
path = './log/MXN/THEOPOULA_lstm_bs{32}_lr{1.0e-03}_epoch{400}_eta{0.0e+00}_beta{1.0e+15}_r{0}_eps{1.0e-04}/history.pkl'
df_theopoula = pkl.load(open(path, 'rb'))

path = './log/MXN/ADAM_lstm_bs{32}_lr{1.0e-03}_eps{1.0e-04}_epoch{400}/history.pkl'

df_adam = pkl.load(open(path, 'rb'))

path = './log/MXN/RMSProp_lstm_bs{32}_lr{1.0e-03}_eps{1.0e-04}_epoch{400}/history.pkl'
df_rms = pkl.load(open(path, 'rb'))

path = './log/MXN/AMSGrad_lstm_bs{32}_lr{1.0e-03}_eps{1.0e-04}_epoch{400}/history.pkl'
df_amsgrad = pkl.load(open(path, 'rb'))

Plot_num = pd.DataFrame(df_adam).shape[1]

fig, ax = plt.subplots(nrows = Plot_num, ncols = 1, figsize=(9,10))
for i, key in zip(range(1, 5), df_theopoula.keys()):
    ax[i-1].plot(df_amsgrad[key], label='AMSGRAD')
    ax[i-1].plot(df_adam[key], label='ADAM')
    ax[i-1].plot(df_rms[key], label='RMSProp')
    ax[i-1].plot(df_theopoula[key], label='TheoPouLa')
    ax[i-1].legend()
    ax[i-1].set_title(key)
fig.tight_layout()  
print('ADAM:  test_loss -',np.array(df_adam['test_loss']).min().item())
print('THEOPOULA:  test_loss -',np.array(df_theopoula['test_loss']).min().item())
print('RMSprop:  test_loss -',np.array(df_rms['test_loss']).min().item())
print('AMSGrad:  test_loss -',np.array(df_amsgrad['test_loss']).min().item())
print('_________________training Loss______________________')
print('ADAM:  Training loss -',np.array(df_adam['training_loss']).min().item())
print('THEOPOULA:  Training loss -',np.array(df_theopoula['training_loss']).min().item())
print('RMSprop:  Training loss -',np.array(df_rms['training_loss']).min().item())
print('AMSGrad:  Training loss -',np.array(df_amsgrad['training_loss']).min().item())
# Out:
# ADAM:  test_loss - 3.628317466529552
# THEOPOULA:  test_loss - 4.073224562685937
# RMSprop:  test_loss - 6.4904779706848785
# AMSGrad:  test_loss - 8.810674913227558
# _________________training Loss______________________
# ADAM:  Training loss - 0.031634687216308736
# THEOPOULA:  Training loss - 0.08219792142215952
# RMSprop:  Training loss - 0.027277379509006792
# AMSGrad:  Training loss - 0.049201241711510676

# %%
key='test_loss'
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(12,8))
#ax.plot(df_amsgrad[key][-200:], label='AMSGRAD')
ax.plot(df_theopoula[key], label='Test')
#ax.plot(df_rms[key][-200:], label='RMSProp')
ax.plot(df_theopoula['training_loss'], label='Train')
ax.legend()
#ax.set_ylim(2, 8)
#ax.set_xlim(50, 400)
ax.set_title(key)
# Out:
# Text(0.5, 1.0, 'test_loss')

# %%
print('Adam MEAN:',np.mean(df_adam[key]))
print('THEOPOULA MEAN:',np.mean(df_theopoula[key]))
# Out:
# Adam MEAN: 10.140114821767748
# THEOPOULA MEAN: 6.452829398443364

# %% [markdown]
# ## Investigation

# %%
#==========================================
## TESTING EVALUATION / OUTPUT OF THE MODEL
#==========================================
input_dim = len(X_train.columns) #sequence length
output_dim = 1
seq_length = 300
hidden_dim = 64
layer_dim = 5
batch_size = 64
dropout = 0.2
n_epochs = 100
#learning_rate = 1e-3
weight_decay = 1e-6

model_params = {'input_dim': input_dim,
                'hidden_dim' : hidden_dim,
                'seq_length' : seq_length,
                'layer_dim' : layer_dim,
                'output_dim' : output_dim,
                'dropout_prob' : dropout}

#Create NN
loss_fn = nn.MSELoss(reduction="mean")
#Set up model 
LSTM_Mod = nn.LSTM(input_dim, hidden_dim, layer_dim, batch_first=True)


#print('Input - Train Loader:',train.shape)
for batch_idx, (inputs, targets) in enumerate(train_loader):
    if batch_idx == 1:
        break    
    print('________BATCH #',batch_idx,'_________________')
    print(' - - - - - -  Inputs - - - - - - - - ')
    print(' - - - - - - Inputs size: - - - - - - \n',inputs.size())
    print(' - - - - - - targets size: - - - - - - \n',targets.size())    
    adjusted_input = inputs.view([batch_size, -1, input_dim]).to(device)
    
    
Test_hidden_state = torch.randn(layer_dim, batch_size, hidden_dim)
Test_cell_state = torch.randn(layer_dim, batch_size, hidden_dim)
test_hidden = (Test_hidden_state,Test_cell_state)

print('Test_hidden_state shape :',Test_hidden_state.shape)
print('Test_cell_state shape :',Test_cell_state.shape)
print('test_hidden shape :',test_hidden[0].shape,test_hidden[1].shape)
fc = nn.Linear(hidden_dim, output_dim)
out, test_hidden = LSTM_Mod(adjusted_input, test_hidden)
print("Output shape: ", out.squeeze()[-1, :].shape)
print("Output shape: ", out.squeeze()[:, -1, :])
#print("Hidden: ", test_hidden)

# %% [markdown]
# ## Miscallaneous Plots

# %%
 THAILAND = DG.Get_FX_MacEcon_Data('TH')
# Out:
# Text(0.5, 0.98, '30day FX Rate Average - Predictions vs real values')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5afecb5f-7d28-4b37-ae51-8d94c0fa9663' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

# %%
fig, ax = plt.subplots(nrows = 3, ncols = 1, figsize=(10,8))

ax[0].plot(THAILAND.index, THAILAND.iloc[:,0], label='Thai Baht per US Dollar', color='#0000ff')
ax[0].tick_params(axis='x')
ax[0].set_xlabel('Time')
ax[0].set_ylabel('FX Rate - Thail vs US Dollar')
ax[0].legend()
ax[0].set_title('Thailand Bhat Exchange Rate')
ax[1].plot(THAILAND.index, THAILAND['Current Account(%GDP)'], label='Current Account(%GDP)',color='#0000ff' )
ax[1].set_xlabel('Time')
#ax[1].tick_params(axis='x')
ax[1].set_ylabel('Current Account(%GDP)')
ax[1].legend()
ax[1].set_title('Thailand Current Account(%GDP)')
ax[2].plot(THAILAND.index, THAILAND['Imports (USD)'], label='Imports (USD)',color='#ff0000' )
ax[2].plot(THAILAND.index, THAILAND['Exports(USD)'], label='Exports (USD)',color='#00bf00' )
ax[2].set_xlabel('Time')
#ax[2].tick_params(axis='x', rotation = 45)
ax[2].set_ylabel('Imports & Exports (USD)')
ax[2].legend()
ax[2].set_title('Thailand Import & Exports (USD)')
fig.tight_layout()

# %%
THAILAND.columns
# Out:
# Index(['THB', 'Yr', 'DoM', 'MoY', 'sin_DoY', 'cos_DoY',
#        'Ave Monthly USD FX Rate', '@OBS_STATUS_x', 'Inflation (CPI) %',
#        '@OBS_STATUS_y', 'Lending Interest Rate %', 'Deposit Interest Rate %',
#        'Exports(USD)', 'Imports (USD)', 'NY.GDP.MKTP.CD',
#        'Real Interest Rate(%)', 'Foreign Exchange Reserves(%)',
#        'M2 Multiplier Growth (%)', 'M2/Reserves', 'Domestic Credit to GDP',
#        'Trade Openness', 'Portfolio Investments(USD)', 'Umemployment rate(%)',
#        'Current Account(%GDP)', 'FDI(%GDP)', 'Total Debt(USD)',
#        'Short Term Debt(USD)', 'Capital Formations(USD)',
#        'Gov Consumption Expendature (%GDP)', 'GDP % Growth', 'THB_30_ave',
#        'THB_60_ave', 'THB_90_ave', 'THB_30_pred'],
#       dtype='object')

# %%
from statsmodels.tsa.stattools import adfuller

#perform augmented Dickey-Fuller test

def describe_stationarity(df_train,df_test):
    
    df_train=df_train.iloc[:,:-15]
    df_test=df_test.iloc[:,:-15]
    columns = df_train.columns
    train_date_range=[]
    train_firsts = []
    train_lasts = []
    train_p_value = []
    train_mean = []
    train_std = []    
    test_date_range=[]
    test_firsts = []
    test_lasts = []
    test_p_value = []
    test_mean = []
    test_std = []

    for i in range(len(columns)):
        col = columns[i]
        train_firsts.append(df_train[[col]].first_valid_index())
        train_lasts.append(df_train[[col]].last_valid_index())
        train_p_value.append(adfuller(df_train[[col]])[1])
        train_mean.append(df_train[col].mean())
        train_std.append(df_train[col].std())    
        
        dt_rng =  str(df_train[[col]].first_valid_index())[:-9]+' - ' + str(df_train[[col]].last_valid_index())[:-9]
        train_date_range.append(dt_rng)
        dt_rng =  str(df_test[[col]].first_valid_index())[:-9]+' - ' + str(df_test[[col]].last_valid_index())[:-9]
        test_date_range.append(dt_rng)
        
        test_firsts.append(df_test[[col]].first_valid_index())
        test_lasts.append(df_test[[col]].last_valid_index())
        test_p_value.append(adfuller(df_test[[col]])[1])
        test_mean.append(df_test[col].mean())
        test_std.append(df_test[col].std())

        
    DF = pd.DataFrame({'Features':columns,
                       'Train Date Range':train_date_range,
                       'Train - p_value':train_p_value,
                       'Train - mean':train_mean,
                       'Train - std deviation': train_std,
                      
                       'Test Date Range':test_date_range,
                       'Test - p_value':test_p_value,
                       'Test - mean':test_mean,
                       'Test - std deviation':test_std})
    
    round_cols = ['Test - p_value','Train - p_value','Test - mean','Train - mean','Test - std deviation','Train - std deviation']
    for i in range(len(round_cols)):
        DF[round_cols[i]]= DF[round_cols[i]].round(decimals=4)

    
    return DF

def plot_stationarity(train,test):
    train=train.iloc[:,:-15]
    test=test.iloc[:,:-15]
    columns = train.columns
    n_cols = len(columns)

    
    fig, ax = plt.subplots(nrows = n_cols, ncols = 1, figsize=(12,22))
    BREAKER=0
    for i in range(len(columns)):
        col = columns[i]
        day_period =300
        train_mean = train[col].rolling(day_period).mean().dropna()
        test_mean = test[col].rolling(day_period).mean().dropna()
        
        train_std = train[col].rolling(day_period).std().dropna()
        test_std = test[col].rolling(day_period).std().dropna()
        
        train_p =train[col].rolling(window=day_period).apply(lambda x: adfuller(x)[1]).dropna()
        test_p =test[col].rolling(window=day_period).apply(lambda x: adfuller(x)[1]).dropna()
        
        #train_idx = test[[col]].index[90:]
        #test_idx = test[[col]].index[90:]

        tr_m, =ax[i].plot(train_mean.index, train_mean, label='Train: mean', color='#00ff7f')
        tr_std, =ax[i].plot(train_std.index, train_std, label='Train: std', color='#ff007f')
        te_m, =ax[i].plot(test_mean.index, test_mean, label='Test: mean', color='#00ff7f', linestyle='--')
        te_std, =ax[i].plot(test_std.index, test_std, label='Test: std', color='#ff007f', linestyle='--')               
        
        ax[i].set_title(f'{col}',fontsize=8)
        ax[i].set_ylabel('Mean & std')
        
        twinax = ax[i].twinx()
        tr_p, =twinax.plot(train_p.index,train_p, label='Train: p_value',color='#0000ff' )
        te_p, =twinax.plot(test_p.index, test_p, label='Test: p_value',color='#0000ff', linestyle='--' )
        #twinax.tick_params(axis='x')
        twinax.set_title(f'{col}',fontsize=8)
        twinax.set_ylabel('p_Value')
        if i != n_cols-1:
            ax[i].tick_params(
                                axis='x',          # changes apply to the x-axis
                                which='both',      # both major and minor ticks are affected
                                bottom='off',      # ticks along the bottom edge are off
                                top='off',         # ticks along the top edge are off
                                labelbottom=False  # labels along the bottom edge are off)
                            )
            twinax.tick_params(
                        axis='x',          # changes apply to the x-axis
                        which='both',      # both major and minor ticks are affected
                        bottom='off',      # ticks along the bottom edge are off
                        top='off',         # ticks along the top edge are off
                        labelbottom=False  # labels along the bottom edge are off)
                                )
            
        if i == n_cols-1:   
            ax[i].set_xlabel('Time')

    h1, l1 = ax[i].get_legend_handles_labels()
    h2, l2 = twinax.get_legend_handles_labels()
    fig.legend(h1+h2, l1+l2, loc='upper left', ncol=3, fontsize=8)
    fig.suptitle(f'{day_period}-Day Rolling Mean, Standard Deviation & p-value',fontsize=14)

# %%
plot_stationarity(X_train,X_test)

# %%
Stationarity = describe_stationarity(X_train,X_test)
Stationarity
# Out:
#                               Features         Train Date Range  \
# 0                                  THB  1981-09-16 - 2012-11-02
# 1                              sin_DoY  1981-09-16 - 2012-11-02
# 2              Ave Monthly USD FX Rate  1981-09-16 - 2012-11-02
# 3                    Inflation (CPI) %  1981-09-16 - 2012-11-02
# 4              Lending Interest Rate %  1981-09-16 - 2012-11-02
# 5              Deposit Interest Rate %  1981-09-16 - 2012-11-02
# 6                         Exports(USD)  1981-09-16 - 2012-11-02
# 7                        Imports (USD)  1981-09-16 - 2012-11-02
# 8                       NY.GDP.MKTP.CD  1981-09-16 - 2012-11-02
# 9                Real Interest Rate(%)  1981-09-16 - 2012-11-02
# 10        Foreign Exchange Reserves(%)  1981-09-16 - 2012-11-02
# 11                      Trade Openness  1981-09-16 - 2012-11-02
# 12               Current Account(%GDP)  1981-09-16 - 2012-11-02
# 13                           FDI(%GDP)  1981-09-16 - 2012-11-02
# ...

# %%
(X_train['THB'].rolling(window=90).apply(lambda x: adfuller(x)[1]).dropna()).index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-226-ded97e8e6cee> in <module>
# ----> 1 (X_train['THB'].rolling(window=90).apply(lambda x: adfuller(x)[1]).dropna()).index()
#
# TypeError: 'DatetimeIndex' object is not callable

# %%
(X_test['THB'].rolling(window=90).sum()).index
#print(X_train[['NY.GDP.MKTP.CD']].index[:-90].shape)
# Out:
# DatetimeIndex(['2012-11-05', '2012-11-06', '2012-11-07', '2012-11-08',
#                '2012-11-09', '2012-11-13', '2012-11-14', '2012-11-15',
#                '2012-11-16', '2012-11-19',
#                ...
#                '2020-07-20', '2020-07-21', '2020-07-22', '2020-07-23',
#                '2020-07-24', '2020-07-27', '2020-07-28', '2020-07-29',
#                '2020-07-30', '2020-07-31'],
#               dtype='datetime64[ns]', name='Date', length=1936, freq=None)

# %%
str(X_test[['THB']].first_valid_index())[:-9] +' - ' + str(X_test[['THB']].last_valid_index())[:-9]
# Out:
# '2012-11-05 - 2020-07-31'

# %%
X_test
# Out:
#               THB   sin_DoY  Ave Monthly USD FX Rate  Inflation (CPI) %  \
# Date
# 2012-11-05  30.81 -0.829677                 30.70580         107.822597
# 2012-11-06  30.74 -0.819972                 30.70580         107.822597
# 2012-11-07  30.71 -0.810025                 30.70580         107.822597
# 2012-11-08  30.67 -0.799839                 30.70580         107.822597
# 2012-11-09  30.62 -0.789418                 30.70580         107.822597
# ...           ...       ...                      ...                ...
# 2020-07-27  31.48 -0.416125                 31.41422         112.540136
# 2020-07-28  31.47 -0.431673                 31.41422         112.540136
# 2020-07-29  31.41 -0.447094                 31.41422         112.540136
# 2020-07-30  31.37 -0.462383                 31.41422         112.540136
# 2020-07-31  31.23 -0.477536                 31.41422         112.540136
#
#             Lending Interest Rate %  Deposit Interest Rate %  Exports(USD)  \
# Date
# ...
